# %%
#Задание 1
a=int(input())
print(a%10,a//10)

# %%
#Задание 2
a=int(input())
print(a%10*10+a//10)

# %%
#Задание 3
a=int(input())
print(a%100)

# %%
#Задание 4
a=int(input())
print(a//10%10)

# %%
#Задание 5
a=int(input())
print(a%10+a//10%10+a//100)

# %%
#Задание 6
a=float(input())
print(int(a*10)%10)

# %%
#Задание 7
print(int(input())//100+1)

# %%
#Задание 8
print((int(input())+3)%7)

# %%
#Задание 9
a=int(input())
a=a%1440
print(a//60,":",a%60,sep='')

# %%
#Задание 10
a=int(input())
b=int(input())
c=int(input())
print(a//2+a%2+b//2+b%2+c//2+c%2)
