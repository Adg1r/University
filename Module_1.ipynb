# %%
#Задание 1
a=int(input())
b=int(input())
c=int(input())
print(a+b+c)

# %%
#Задание 2
a=float(input())
h=float(input())
print(a*h/2)

# %%
# Задание 3
print("Привет, ",input(),"!",sep='')

# %%
# Задание 4
a=int(input())
print("Следующее число для числа ",a,": ",a+1,"\n","Предыдущее число для числа ",a,": ",a-1,sep="")

# %%
# Задание 5
N=int(input())
K=int(input())
print("Яблок у студентов: ",K//N,", в корзине: ",N%K,sep='')

# %%
# Задание 6
N=int(input())
print(N//3600,N//60)

# %%
# Задание 7
h1=int(input())
m1=int(input())
s1=int(input())
h2=int(input())
m2=int(input())
s2=int(input())
print(h2*3600+m2*60+s2-h1*3600-m1*60-s1)
