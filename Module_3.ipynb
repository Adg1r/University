# %%
print(len(input.split()))

# %%
a,b=map(str,input().split())
print(b,a)

# %%
s = input()
first=s.find('f')
last=s.rfind('f')
if first == -1:
    print(-1)
elif first == last:
    print(first + 1)
else:
    print(first + 1, last + 1)

# %%
a=input()
b=a.replace("1","one")
print(b)

# %%
a=input()
b=a.replace("@","")
print(b)
